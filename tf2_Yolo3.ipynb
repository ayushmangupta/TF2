# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushmangupta/TF2/blob/master/tf2_Yolo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
#!pip  install -q tensorflow-gpu==2.0.0-beta1
#git clone https://github.com/zzh8829/yolov3-tf2.git
import os
import datetime
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as tfk
import numpy as np
import tensorflow.keras.layers as tfkl
import tensorflow_datasets as tfds

# %%
os.chdir("yolov3-tf2")

# %%
#!pip install -r requirements.txt

# %%
# !ls
# Out:
# checkpoints  detect.py	      export_tfserving.py  requirements.txt
# convert.py   detect_video.py  LICENSE		   train.py
# data	     environment.yml  README.md		   yolov3_tf2

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights -O data/yolov3-tiny.weights
# !python convert.py --weights ./data/yolov3-tiny.weights --output ./checkpoints/yolov3-tiny.tf --tiny
# Out:
# --2019-07-07 08:50:52--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘data/yolov3-tiny.weights’
#
# data/yolov3-tiny.we 100%[===================>]  33.79M  91.2MB/s    in 0.4s
#
# 2019-07-07 08:50:53 (91.2 MB/s) - ‘data/yolov3-tiny.weights’ saved [35434956/35434956]
#
# 2019-07-07 08:50:57.107981: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-07 08:50:57.147972: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python detect.py --weights ./checkpoints/yolov3-tiny.tf --tiny --image ./data/street.jpg
# Out:
# 2019-07-07 08:51:38.012158: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-07 08:51:38.017667: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-07-07 08:51:38.024393: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2019-07-07 08:51:38.024457: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:153] kernel driver does not appear to be running on this host (86932b06be0b): /proc/driver/nvidia/version does not exist
# 2019-07-07 08:51:38.026575: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-07-07 08:51:38.026840: I tensorflow/compiler/xla/service/service.cc:162] XLA service 0x197e680 executing computations on platform Host. Devices:
# ...

# %%
plt.imshow(plt.imread("output.jpg"))
